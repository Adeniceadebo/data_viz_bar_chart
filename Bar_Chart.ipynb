# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
df_used_cars = pd.read_csv('car_brands_and_listings.csv')
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize=(9, 6))
plt.bar(x = df_used_cars['Brand'], height = df_used_cars['Cars Listings'], color = 'midnightblue')
plt.xticks(rotation=45, ha='right', fontsize=13)
plt.xlabel('Car Brands', fontsize=14, fontweight='bold')
plt.ylabel('Number of Listings', fontsize=13, fontweight='bold')
plt.title('Used Car Listings by Brand', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('used_cars_by_brand.png', dpi=300)
plt.show()
